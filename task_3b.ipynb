# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitha-4032007/python-tasks/blob/main/task_3b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import pow

def compute_armstrong(x):
    # Convert number to string to find number of digits
    n = len(str(x))
    # Compute the sum of each digit raised to the power n
    armstrong_sum = sum(pow(int(i), n) for i in str(x))
    return armstrong_sum == x

# Get input from user
number = int(input("Enter a number: "))

# Check and display result
if compute_armstrong(number):
    print(f"{number} is an Armstrong number")
else:
    print(f"{number} is not an Armstrong number")
# Out:
# Enter a number: 123
# 123 is not an Armstrong number
