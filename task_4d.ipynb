# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitha-4032007/python-tasks/blob/main/task_4d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def min_paint_balloons(s):

    amber_count = s.count('a')
    brass_count = s.count('b')


    min_paint = min(amber_count, brass_count)
    return min_paint


T = int(input("Enter the total number of test cases: "))

for i in range(T):

    s = input("Enter balloon colors (a and b only): ").strip()


    print(min_paint_balloons(s))
# Out:
# Enter the total number of test cases: 2
# Enter balloon colors (a and b only): aaa bb a
# 2
# Enter balloon colors (a and b only): aababbb
# 3
