# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitha-4032007/python-tasks/blob/main/task_3c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

def edistance(x, y):
    # Correct formula: square differences
    distance = math.sqrt((y[0] - x[0])**2 + (y[1] - x[1])**2)
    return distance
    from euclidean_distance_module import edistance

X = (1, 3)  # Tuple
Y = (2, 3)

result = edistance(X, Y)
print("Euclidean distance between X and Y:", result)
# Out:
# Euclidean distance between X and Y: 1.0
