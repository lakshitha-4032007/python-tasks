# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitha-4032007/python-tasks/blob/main/task_3a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime

input_date = input("Enter the date in MM DD YYYY format: ")
month, day, year = map(int, input_date.split())

if 2000 < year < 3000:
 x = datetime.datetime(year, month, day)

 day_name = x.strftime("%A").upper()
 print(day_name)
else:
 print("Year is not within the specified constraints.")
# Out:
# Enter the date in MM DD YYYY format: 04 03 2007
# TUESDAY
