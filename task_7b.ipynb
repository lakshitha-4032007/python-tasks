# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitha-4032007/python-tasks/blob/main/task_7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def cube_product_of_natural_numbers(n):
    product = 1
    for i in range(1, n + 1):
        product *= i ** 3
    return product

# Get input from the user
n = int(input("Enter the value of N: "))

# Calculate the cube product
result = cube_product_of_natural_numbers(n)

# Output the result
print("Cube product of the first", n, "natural numbers is:", result)
# Out:
# Enter the value of N: 5
# Cube product of the first 5 natural numbers is: 1728000
