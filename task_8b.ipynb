# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitha-4032007/python-tasks/blob/main/task_8b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def squares():
    for i in range(5):
        yield i ** 2


squares_generator = squares()


for square in squares_generator:
    print(square)
# Out:
# 0
# 1
# 4
# 9
# 16
