# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitha-4032007/python-tasks/blob/main/task_4b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alist = []


for i in range(int(input("Enter number of students: "))):
    name = input("Enter name: ")
    score = float(input("Enter score: "))
    alist.append([name, score])


second_highest = sorted(set([score for name, score in alist]))[1]


names = sorted([name for name, score in alist if score == second_highest])


print("\n".join(names))
# Out:
# Enter number of students: 2
# Enter name: priya
# Enter score: 55
# Enter name: rithh
# Enter score: 69
# rithh
